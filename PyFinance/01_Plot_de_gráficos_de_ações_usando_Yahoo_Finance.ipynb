# %% [markdown]
# <a href="https://colab.research.google.com/github/Bonacelli/pycourses/blob/master/PyFinance/01_Plot_de_gr%C3%A1ficos_de_a%C3%A7%C3%B5es_usando_Yahoo_Finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
yf.pdr_override()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22409 sha256=282190adcd95bfe57144b43887ded32aba418f6666e6b44e1ca32f7419cbef22
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a2t2cfr1/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# Successfully built yfinance
# ...

# %% [markdown]
# # Obtendo os dados do mercado

# %%
ibov = web.get_data_yahoo('^BVSP')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1993-04-27  24.799999  25.400000  24.500000  24.500000  24.500000       0
# 1993-04-28  24.500000  24.600000  23.700001  24.299999  24.299999       0
# 1993-04-29  24.299999  24.799999  23.700001  23.700001  23.700001       0
# 1993-04-30  23.700001  24.200001  23.700001  24.100000  24.100000       0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000  24.100000       0

# %%
ibov.tail()
# Out:
#                      Open           High  ...      Adj Close    Volume
# Date                                      ...
# 2020-07-28  104477.000000  104663.000000  ...  104109.000000   9087100
# 2020-07-29  104112.000000  105704.000000  ...  105605.000000   9238300
# 2020-07-30  105605.000000  105607.000000  ...  105009.000000   9591700
# 2020-07-31  105010.000000  105462.000000  ...  102912.000000  12929300
# 2020-08-03  102912.867188  103863.328125  ...  102829.960938         0
#
# [5 rows x 6 columns]

# %%
ibov["Close"].plot(figsize=(22,8), label="IBOV")
ibov["Close"].rolling(21).mean().plot(label="MM21")
ibov["Close"].rolling(200).mean().plot(label="MM200")
plt.legend()

# %%
ibov_fatiado = ibov[ibov.index.year == 2008]
ibov_fatiado["Close"].plot(figsize=(22,8), label="IBOV")
ibov_fatiado["Close"].rolling(21).mean().plot(label="MM21")
ibov_fatiado["Close"].rolling(200).mean().plot(label="MM200")
plt.legend()

# %%
ibov_fatiado = ibov[(ibov.index.year >= 2008) & (ibov.index.year <= 2015)]
ibov_fatiado["Close"].plot(figsize=(22,8), label="IBOV")
ibov_fatiado["Close"].rolling(21).mean().plot(label="MM21")
ibov_fatiado["Close"].rolling(200).mean().plot(label="MM200")
plt.legend()

# %%
ibov_fatiado = ibov[ibov.index.month == 12]
ibov_fatiado.tail(50)
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2017-12-12   72800.0   73814.0   71798.0   73814.0    73814.0  2956100
# 2017-12-13   73827.0   74622.0   72569.0   72914.0    72914.0  4494700
# 2017-12-14   72913.0   72913.0   71969.0   72429.0    72429.0  3491800
# 2017-12-15   72428.0   73069.0   72277.0   72608.0    72608.0  4659500
# 2017-12-18   72621.0   73519.0   72621.0   73115.0    73115.0  3202900
# 2017-12-19   73122.0   73139.0   72347.0   72680.0    72680.0  2351600
# 2017-12-20   72680.0   73492.0   72680.0   73367.0    73367.0  2219600
# 2017-12-21   73367.0   75133.0   73265.0   75133.0    75133.0  3056400
# 2017-12-22   75128.0   75227.0   74623.0   75187.0    75187.0  1906900
# 2017-12-26   75187.0   75758.0   74924.0   75688.0    75688.0  1579700
# 2017-12-27   75708.0   76293.0   75708.0   76073.0    76073.0  1792200
# 2017-12-28   76077.0   76437.0   76077.0   76402.0    76402.0  2083000
# ...

# %%
ibov_fatiado = ibov[ibov.index.day == 15]
ibov_fatiado.tail(10)
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2019-04-15   92875.0   93723.0   92697.0   93083.0    93083.0   4629800
# 2019-05-15   92088.0   92088.0   90295.0   91623.0    91623.0   4791900
# 2019-07-15  103909.0  104578.0  103495.0  103803.0   103803.0   3995500
# 2019-08-15  100262.0  101014.0   98200.0   99057.0    99057.0   6585300
# 2019-10-15  104299.0  105048.0  104052.0  104490.0   104490.0   4093400
# 2020-01-15  117632.0  117632.0  116188.0  116414.0   116414.0   5569400
# 2020-04-15   79911.0   80035.0   77546.0   78831.0    78831.0   9758400
# 2020-05-15   79011.0   79538.0   77426.0   77557.0    77557.0  11718200
# 2020-06-15   92780.0   93112.0   90148.0   92376.0    92376.0  13317500
# 2020-07-15  100444.0  102114.0  100444.0  101791.0   101791.0   9285600

# %%
vale = web.get_data_yahoo('VALE3.SA', start='2019-08-03', end='2020-08-03')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
vale["Close"].plot(figsize=(22,8), label="Vale")
vale["Close"].rolling(21).mean().plot(label="MM21")
vale["Close"].rolling(200).mean().plot(label="MM200")
plt.legend()

# %%
itausa = web.get_data_yahoo('ITSA4.SA', start='2010-08-03', end='2020-08-03')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
itausa["Close"].plot(figsize=(22,8), label="Vale")
itausa["Close"].rolling(21).mean().plot(label="MM21")
itausa["Close"].rolling(200).mean().plot(label="MM200")
plt.legend()
